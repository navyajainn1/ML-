# %%
# Intoduction to pandas
# pandas is an open-source library of python which is used for handling data mainpulations.

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
# Data structure of pandas
# (1). Series
# (2). DataFrame

# %%
# 1. Series ---> It is one-dimensional array and it retuns only values.

# %%
se = pd.Series([1,45,32,23,8,28])
se
# Out:
# 0     1
# 1    45
# 2    32
# 3    23
# 4     8
# 5    28
# dtype: int64

# %%
type(se)
# Out:
# pandas.core.series.Series

# %%
# 2. DataFrame ---> It is multi-dimensional array and it returns data in rows and columns.

# %%
# We have to create a dataframe of employees in which columns are
# emp_id,emp_name,department,salary,working_hours

# %%
dict = {'Emp_id':[101,102,103,104],
        'Emp_name':['Amit','Ashok','Priya','Priyanka'],
        'Department':['IT','Operations','IT','Operations'],
        'Salary':[50000,65000,55000,60000],
        'Working_hours':[9,8,9,8]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#    Emp_id  Emp_name  Department  Salary  Working_hours
# 0     101      Amit          IT   50000              9
# 1     102     Ashok  Operations   65000              8
# 2     103     Priya          IT   55000              9
# 3     104  Priyanka  Operations   60000              8

# %%
# How can we export our dataframe into csv

# %%
df.to_csv('emp_info.csv') # to_csv means export your data into csv

# %%
df.to_csv('new_emp_info.csv',index=False) # index=False means it will remove unnamed column.

# %%
df = pd.read_csv('/content/flipkart.csv')

# %%
df
# Out:
#                                           Model Name      Model Name.1  \
# 0                OnePlus Nord 5 5G (Dry Ice, 256 GB)       895 Ratings
# 1               OnePlus 13R 5G (Nebula Noir, 512 GB)     1,666 Ratings
# 2               OnePlus 13R 5G (Nebula Noir, 256 GB)     3,967 Ratings
# 3              OnePlus 13R 5g (Astral Trail, 256 GB)     3,967 Ratings
# 4           OnePlus Nord 5 5G (Phantom Grey, 512 GB)       895 Ratings
# 5              IQOO Neo 10 (Titanium Chrome, 512 GB)       117 Ratings
# 6    Samsung Galaxy A55 5G (Awesome Iceblue, 256 GB)       619 Ratings
# 7      MOTOROLA Razr 60 (PANTONE Spring Bud, 256 GB)     1,684 Ratings
# 8           OnePlus Nord 5 5G (Marble Sands, 256 GB)       895 Ratings
# 9                 Xiaomi 14 CIVI (Aqua Blue, 512 GB)     1,022 Ratings
# 10           vivo V30 Pro 5G (Classic Black, 256 GB)     7,407 Ratings
# 11          OnePlus Nord 5 5G (Phantom Grey, 256 GB)       895 Ratings
# ...

# %%
df = pd.read_csv('/content/Best restaurants in jaipur.csv')

# %%
df
# Out:
#                                       Restaurant name Type of restaurant  \
# 0                                  Skyfall Restaurant    ·  · Restaurant
# 1                                       Suvarna Mahal  ·  · North Indian
# 2                                  Peacock Restaurant  ·  · North Indian
# 3                                                 NaN                NaN
# 4                                    Govindam Retreat    ·  · Restaurant
# 5                             Handi restaurant jaipur    ·  · Restaurant
# 6                 J Brew & Kitchen Rooftop Restaurant     · North Indian
# 7                          The Forresta Kitchen & Bar       ·  · Brewpub
# 8                           Rustic - Inspired Kitchen     · North Indian
# 9                                     Stardust Jaipur  ·  · North Indian
# 10                  Nouba Restaurant & Rooftop Lounge       · Restaurant
# 11  The DeIicious Yard // family restaurants in ja...    ·  · Restaurant
# ...

# %%
df = pd.read_csv('/content/flipkart shoes.csv')

# %%
df
# Out:
#          Brand                                        Description  \
# 0        Asics               GEL-CUMULUS 26 Running Shoes For Men
# 1        Asics            GT-1000 LE 2 (2E) Running Shoes For Men
# 2  New Balance                               327 Sneakers For Men
# 3  New Balance                              997R Sneakers For Men
# 4        Asics                HYPER SPEED 5 Running Shoes For Men
# 5        Asics                   GT-1000 13 Running Shoes For Men
# 6     Skechers                               327 Sneakers For Men
# 7     Skechers  Skechers Mens D'Lux Walker-Commuter Casual Lac...
# 8      SAUCONY                 PROGRID TRIUMPH 4 Sneakers For Men
# 9        Asics                 GEL-PULSE 16 Running Shoes For Men
#
#   Discounted Price Actual Price Discount
# 0           ₹5,163      ₹10,999  53% off
# 1           ₹4,799       ₹9,999  52% off
# 2           ₹4,800       ₹9,999  51% off
# 3           ₹5,760      ₹11,999  51% off
# ...

# %%
df = pd.read_csv('/content/Top 10 places in mussorie.csv')
df
# Out:
#                         Place  Ratings Reviews      Best known for
# 0                   Cloud end      4.5  (4.3K)  Tourist attraction
# 1       Lal Tibba Scenic Cafe      4.1   (19K)         Scenic spot
# 2       Atal Udhyan Mussoorie      4.2  (6.3K)                Park
# 3        George Everest House      4.5  (9.6K)         Observatory
# 4                Bhatta falls      4.3  (8.5K)  Tourist attraction
# 5            Camels Back Road      NaN     NaN               Route
# 6         Gun Hill, Mussoorie      4.0   (11K)  Tourist attraction
# 7                   Mall Road      4.4  (1.3K)      Notable street
# 8                     Landour      NaN     NaN        Sublocality1
# 9               Christ Church      4.3    -406              Church
# 10             Mussoorie Lake      3.8    -556  Tourist attraction
# 11   Benog Wildlife Sanctuary      4.4    -195       Wildlife park
# 12        Chardukan Mussoorie      4.3  (7.2K)           Fast Food
# ...

# %%
df = pd.read_csv('/content/covid_toy.csv')

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.sample(2)
# Out:
#     age  gender  fever   cough       city has_covid
# 87   47    Male  101.0  Strong  Bangalore        No
# 26   19  Female  100.0    Mild    Kolkata       Yes

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'].mean()
# Out:
# np.float64(100.84444444444445)

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df = pd.read_csv('/content/placement - placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 38   6.0          8.72       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4,:3]    # iloc[row_range , column_range]
top_left_corner_df                     # it excludes the last value in range and only take range in numerical
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 , ['cgpa','placed']]  # loc[row_range,column_range]
# it includes all values and accept range in both numerical and categorial
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty # it returns True if there is any missing value in the dataset
b
# Out:
# False

# %%
df.isnull().sum() # it tells how many null values are present
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df = df.dropna() # it delets the row in which null values are present

# %%
df.ndim
# Out:
# 2

# %%
print(df.shape)
print(df.shape[0])  # total rows in data
print(df.shape[1])  # total columns in data
# Out:
# (100, 3)
# 100
# 3

# %%
df.size
# Out:
# 300

# %%
df.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')    # by default ascending order
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
p = df.sort_values(by = 'resume_score',ascending=False)   # descending order
p
# Out:
#    cgpa  resume_score  placed
# 69    8          9.06       1
# 2     8          8.86       1
# 65    6          8.75       0
# 38    6          8.72       0
# 17    7          8.71       1
# ..  ...           ...     ...
# 1     6          5.17       0
# 41    8          5.15       1
# 13    8          5.09       1
# 87    5          5.05       0
# 94    8          4.95       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(int)

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1
# 3     6          7.27       1
# 4     7          7.30       1

# %%
df['cgpa'] = df['cgpa'].astype(str)

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['resume_score'] = df['resume_score'].astype(int)

# %%
df.dtypes
# Out:
# cgpa            object
# resume_score     int64
# placed           int64
# dtype: object

# %%
df['resume_score'] = df['resume_score'].add(5)

# %%
df.head()
# Out:
#   cgpa  resume_score  placed
# 0    8            11       1
# 1    6            10       0
# 2    8            13       1
# 3    6            12       1
# 4    7            12       1

# %%
df.count()  # It counts the values a column contain
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()  # It returns the maximum value in a column
# Out:
# cgpa             9
# resume_score    14
# placed           1
# dtype: object

# %%
df.min()  # It retuns the minimum value in a column
# Out:
# cgpa            5
# resume_score    9
# placed          0
# dtype: object

# %%
g = df.filter(items=['cgpa','placed'])
g

# df[['cgpa','placed']] -->  Second option of filtering
# Out:
#    cgpa  placed
# 0     8       1
# 1     6       0
# 2     8       1
# 3     6       1
# 4     7       1
# ..  ...     ...
# 95    6       0
# 96    8       1
# 97    6       0
# 98    8       1
# 99    6       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items=[5,6] , axis=0)  # In pandas axis = 0  means row wise operation
s
# Out:
#   cgpa  resume_score  placed
# 5    8            11       1
# 6    5            12       0

# %%
t = df.filter(like='5',axis=0)
t
# Out:
#    cgpa  resume_score  placed
# 5     8            11       1
# 15    8            10       1
# 25    7            10       1
# 35    8            12       1
# 45    8            10       1
# 50    8            11       1
# 51    6            12       0
# 52    5            12       0
# 53    6            12       0
# 54    5            12       0
# 55    6            11       1
# 56    6            11       0
# 57    6            12       0
# 58    6            12       0
# 59    5            12       0
# 65    6            13       0
# 75    6            12       1
# 85    6            10       0
# 95    6            11       0

# %%
p = df.rename(columns = {'cgpa':'updated_cgpa' , 'resume_score':'semester_marks'})
p
# Out:
#    updated_cgpa  semester_marks  placed
# 0             8              11       1
# 1             6              10       0
# 2             8              13       1
# 3             6              12       1
# 4             7              12       1
# ..          ...             ...     ...
# 95            6              11       0
# 96            8              12       1
# 97            6              12       0
# 98            8              10       1
# 99            6              11       0
#
# [100 rows x 3 columns]

# %%
df['half'] = df['resume_score'].where(df['resume_score']>11,other=0)
df.head(5)
# Out:
#   cgpa  resume_score  placed  half
# 0    8            11       1     0
# 1    6            10       0     0
# 2    8            13       1    13
# 3    6            12       1    12
# 4    7            12       1    12

# %%
df.groupby('placed').size()
# Out:
# placed
# 0    50
# 1    50
# dtype: int64
