# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Customer_Call.xlsx - Call List.csv')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.tail()
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 16  121 Paper Avenue, Pennsylvania             Yes             No
# 17                 3498 Super Lane               Y            NaN
# 18                             N/a             N/a            Yes
# 19     910 Tatooine Road, Tatooine             Yes              N
# 20     910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %%
df.sample()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number                     Address  \
# 9        1010      Peter    Parker  123-545-5421  25th Main Street, New York
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column
# 9             Yes             No               True

# %%
df.describe()
# Out:
#         CustomerID
# count    21.000000
# mean   1010.952381
# std       6.127611
# min    1001.000000
# 25%    1006.000000
# 50%    1011.000000
# 75%    1016.000000
# max    1020.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df['Do_Not_Contact'].value_counts()
# Out:
# Do_Not_Contact
# No     9
# N      4
# Yes    3
# Y      1
# Name: count, dtype: int64

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].fillna('No')

# %%
df=df.dropna()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876|678|3469
# 9         1010      Peter       Parker  123-545-5421
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# ...

# %%
df.isna().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CustomerID            int64
# First_Name           object
# Last_Name            object
# Phone_Number         object
# Address              object
# Paying Customer      object
# Do_Not_Contact       object
# Not_Useful_Column      bool
# dtype: object

# %%
df.empty
# Out:
# False

# %%
print(df.shape)
print(df.shape[0]) #row
print(df.shape[1]) #column
# Out:
# (18, 8)
# 18
# 8

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 144

# %%
df['Paying Customer']=df['Paying Customer'].map({'Y':'1','N':'0','Yes':'1','No':'0'})
# Out:
# /tmp/ipython-input-2331056362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].map({'Y':'1','N':'0','Yes':'1','No':'0'})

# %%
df['Paying Customer'].value_counts()
# Out:
# Paying Customer
# 1    12
# 0     5
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      1
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df['Paying Customer']=df['Paying Customer'].fillna('1')
# Out:
# /tmp/ipython-input-1158532226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer']=df['Paying Customer'].fillna('1')

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
paying=df['Paying Customer'].value_counts()

# %%
paying=pd.DataFrame(paying)
paying
# Out:
#                  count
# Paying Customer
# 1                   13
# 0                    5

# %%
df.sort_values(by = 'First_Name')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 1         1002       Abed        Nadir  123/643/9775
# 20        1020     Anakin    Skywalker  876|678|3469
# 19        1020     Anakin    Skywalker  876|678|3469
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 12        1013        Don       Draper  123-543-2345
# 3         1004     Dwight      Schrute  123-543-2345
# 0         1001      Frodo      Baggins  123-545-5421
# 11        1012      Harry    ...Potter    7066950392
# 4         1005        Jon         Snow  876|678|3469
# 13        1014     Leslie        Knope  876|678|3469
# 16        1017   Michael         Scott  123/643/9775
# 9         1010      Peter       Parker  123-545-5421
# 5         1006        Ron      Swanson  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 7         1008   Sherlock       Holmes  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# ...

# %%
df.sort_values(by = 'First_Name',ascending=False)
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 2         1003     Walter       /White    7066950392
# 14        1015       Toby  Flenderson_  304-762-2467
# 7         1008   Sherlock       Holmes  876|678|3469
# 15        1016        Ron      Weasley  123-545-5421
# 5         1006        Ron      Swanson  304-762-2467
# 9         1010      Peter       Parker  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 13        1014     Leslie        Knope  876|678|3469
# 4         1005        Jon         Snow  876|678|3469
# 11        1012      Harry    ...Potter    7066950392
# 0         1001      Frodo      Baggins  123-545-5421
# 3         1004     Dwight      Schrute  123-543-2345
# 12        1013        Don       Draper  123-543-2345
# 18        1019      Creed       Braton           N/a
# 17        1018      Clark         Kent    7066950392
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
# ...

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].map({'Y':'1','N':'0','Yes':'1','No':'0'})
# Out:
# /tmp/ipython-input-2435792342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact']=df['Do_Not_Contact'].map({'Y':'1','N':'0','Yes':'1','No':'0'})

# %%
df['Do_Not_Contact'].value_counts()
# Out:
# Do_Not_Contact
# 0    14
# 1     4
# Name: count, dtype: int64

# %%
df.loc[0:,['First_Name','Paying Customer']]
# Out:
#    First_Name Paying Customer
# 0       Frodo               1
# 1        Abed               0
# 2      Walter               0
# 3      Dwight               1
# 4         Jon               1
# 5         Ron               1
# 7    Sherlock               0
# 9       Peter               1
# 11      Harry               1
# 12        Don               1
# 13     Leslie               1
# 14       Toby               0
# 15        Ron               0
# 16   Michael                1
# 17      Clark               1
# 18      Creed               1
# 19     Anakin               1
# 20     Anakin               1

# %%
df.iloc[:5,1:6]
# Out:
#   First_Name Last_Name  Phone_Number                                Address  \
# 0      Frodo   Baggins  123-545-5421                  123 Shire Lane, Shire
# 1       Abed     Nadir  123/643/9775                    93 West Main Street
# 2     Walter    /White    7066950392                     298 Drugs Driveway
# 3     Dwight   Schrute  123-543-2345  980 Paper Avenue, Pennsylvania, 18503
# 4        Jon      Snow  876|678|3469                       123 Dragons Road
#
#   Paying Customer
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1

# %%
df.filter(items=['First_Name','Do_Not_Contact'])
# Out:
#    First_Name Do_Not_Contact
# 0       Frodo              0
# 1        Abed              1
# 2      Walter              0
# 3      Dwight              1
# 4         Jon              0
# 5         Ron              1
# 7    Sherlock              0
# 9       Peter              0
# 11      Harry              0
# 12        Don              0
# 13     Leslie              0
# 14       Toby              0
# 15        Ron              0
# 16   Michael               0
# 17      Clark              0
# 18      Creed              1
# 19     Anakin              0
# 20     Anakin              0

# %%
sns.barplot(data=paying,x='Paying Customer',y='count',color='blue')
# Out:
# <Axes: xlabel='Paying Customer', ylabel='count'>

# %%
sns.countplot(x=df['Do_Not_Contact'])
# Out:
# <Axes: xlabel='Do_Not_Contact', ylabel='count'>
